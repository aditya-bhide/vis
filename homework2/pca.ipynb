# %%
from sklearn.datasets import load_breast_cancer
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import numpy as np
import math
import pandas as pd
import pprint


breast = load_breast_cancer()
features = breast.feature_names
breast_data = breast.data

dataset = pd.DataFrame(breast_data)
dataset.columns = features

std_sklr = StandardScaler()
x = std_sklr.fit_transform(X = breast_data)
pca_breast = PCA(n_components=10)
principalComponents_breast = pca_breast.fit_transform(x)
eigen_values = pca_breast.explained_variance_

def get_data():
    scree_plot = {}
    eigen_total = sum(eigen_values)
    variance_percentage = []
    for i in  eigen_values:
        variance_percentage.append((i/eigen_total)*100)
    
    cumulative_variance = []
    temp = 0
    for i in variance_percentage:
        temp += i
        cumulative_variance.append(temp)
 
    for i in range(0, len(eigen_values)):
        scree_plot[i+1] = {"variance_percentage" : variance_percentage[i], "cumulative_variance": cumulative_variance[i]}
    return scree_plot

def get_top_pca():
    data_send = {}
    count = 0
    for i, j, k in zip(features, pca_breast.components_[0], pca_breast.components_[1]):
        data_send[count] = {}
        data_send[count]["name"] = i
        data_send[count]["pc1"] = j
        data_send[count]["pc2"] = k
        count += 1
    return data_send

def get_top_four_features(di = 3):
    squared_value = pca_breast.components_[:di] ** 2

    features_dict = {}
    for i in range(0, len(squared_value[0])):
        total = 0
        for j in range(0, len(squared_value)):
            total += squared_value[j][i]
        features_dict[features[i]] = math.sqrt(total)

    sorted_features_dict = [k for k, v in sorted(features_dict.items(), key=lambda item: item[1])]
    sorted_features_dict = sorted_features_dict[::-1]
    best_four_features = sorted_features_dict[:4]
    
    values_best_best_four_features = {}
    for i in best_four_features:
        values_best_best_four_features[i] = features_dict[i]

    return values_best_best_four_features

def get_top_four_matrix(di = 3):
    imp_features = get_top_four_features(di)
    imp_features_arr = [i for i in imp_features]
    np_data = dataset[imp_features_arr].to_numpy()
    send_data = {}
    for i in range(0, np_data.shape[0]):
        send_data[i] = {}
        for j in range(0, len(imp_features_arr)):
            send_data[i][imp_features_arr[j]] = np_data[i][j]
    
    return send_data
# Out:
# {0: {'mean fractal dimension': 0.07871,
#      'smoothness error': 0.006399,
#      'texture error': 0.9053,
#      'worst fractal dimension': 0.1189},
#  1: {'mean fractal dimension': 0.05667,
#      'smoothness error': 0.005225,
#      'texture error': 0.7339,
#      'worst fractal dimension': 0.08902},
#  2: {'mean fractal dimension': 0.05999,
#      'smoothness error': 0.00615,
#      'texture error': 0.7869,
#      'worst fractal dimension': 0.08758},
#  3: {'mean fractal dimension': 0.09744,
#      'smoothness error': 0.00911,
#      'texture error': 1.156,
#      'worst fractal dimension': 0.173},
#  4: {'mean fractal dimension': 0.05883,
#      'smoothness error': 0.01149,
#      'texture error': 0.7813,
#      'worst fractal dimension': 0.07678},
#  5: {'mean fractal dimension': 0.07613,
#      'smoothness error': 0.00751,
#      'texture error': 0.8902,
#      'worst fractal dimension': 0.1244},
#  6: {'mean fractal dimension': 0.05742,
#      'smoothness error': 0.004314,
#      'texture error': 0.7732,
#      'worst fractal dimension': 0.08368},
#  7: {'mean fractal dimension': 0.07451,
#      'smoothness error': 0.008805,
#      'texture error': 1.377,
#      'worst fractal dimension': 0.1151},
#  8: {'mean fractal dimension': 0.07389,
#      'smoothness error': 0.005731,
#      'texture error': 1.002,
#      'worst fractal dimension': 0.1072},
#  9: {'mean fractal dimension': 0.08243,
#      'smoothness error': 0.007149,
#      'texture error': 1.599,
#      'worst fractal dimension': 0.2075},
#  10: {'mean fractal dimension': 0.05697,
#       'smoothness error': 0.004029,
#       'texture error': 1.187,
#       'worst fractal dimension': 0.08452},
#  11: {'mean fractal dimension': 0.06082,
#       'smoothness error': 0.005771,
#       'texture error': 0.9849,
#       'worst fractal dimension': 0.1048},
#  12: {'mean fractal dimension': 0.078,
#       'smoothness error': 0.003139,
#       'texture error': 3.568,
#       'worst fractal dimension': 0.1023},
#  13: {'mean fractal dimension': 0.05338,
#       'smoothness error': 0.009769,
#       'texture error': 1.078,
#       'worst fractal dimension': 0.06287},
#  14: {'mean fractal dimension': 0.07682,
#       'smoothness error': 0.006429,
#       'texture error': 1.169,
#       'worst fractal dimension': 0.1431},
#  15: {'mean fractal dimension': 0.07077,
#       'smoothness error': 0.005607,
#       'texture error': 1.033,
#       'worst fractal dimension': 0.1341},
#  16: {'mean fractal dimension': 0.05922,
#       'smoothness error': 0.005718,
#       'texture error': 1.24,
#       'worst fractal dimension': 0.08216},
#  17: {'mean fractal dimension': 0.07356,
#       'smoothness error': 0.007026,
#       'texture error': 1.073,
#       'worst fractal dimension': 0.1142},
#  18: {'mean fractal dimension': 0.05395,
#       'smoothness error': 0.006494,
#       'texture error': 1.017,
#       'worst fractal dimension': 0.07615},
#  19: {'mean fractal dimension': 0.05766,
#       'smoothness error': 0.008462,
#       'texture error': 0.7886,
#       'worst fractal dimension': 0.07259},
#  20: {'mean fractal dimension': 0.06811,
#       'smoothness error': 0.004097,
#       'texture error': 0.7477,
#       'worst fractal dimension': 0.08183},
#  21: {'mean fractal dimension': 0.06905,
#       'smoothness error': 0.009606,
#       'texture error': 0.9768,
#       'worst fractal dimension': 0.07773},
#  22: {'mean fractal dimension': 0.07032,
#       'smoothness error': 0.006789,
#       'texture error': 0.7096,
#       'worst fractal dimension': 0.09946},
#  23: {'mean fractal dimension': 0.05278,
#       'smoothness error': 0.004728,
#       'texture error': 1.127,
#       'worst fractal dimension': 0.07526},
#  24: {'mean fractal dimension': 0.0633,
#       'smoothness error': 0.006048,
#       'texture error': 0.9017,
#       'worst fractal dimension': 0.09564},
#  25: {'mean fractal dimension': 0.07413,
#       'smoothness error': 0.008029,
#       'texture error': 0.976,
#       'worst fractal dimension': 0.1059},
#  26: {'mean fractal dimension': 0.06924,
#       'smoothness error': 0.004452,
#       'texture error': 0.9832,
#       'worst fractal dimension': 0.1275},
#  27: {'mean fractal dimension': 0.05699,
#       'smoothness error': 0.01075,
#       'texture error': 1.849,
#       'worst fractal dimension': 0.07421},
#  28: {'mean fractal dimension': 0.0654,
#       'smoothness error': 0.005233,
#       'texture error': 1.012,
#       'worst fractal dimension': 0.09876},
#  29: {'mean fractal dimension': 0.06149,
#       'smoothness error': 0.005627,
#       'texture error': 0.8225,
#       'worst fractal dimension': 0.07919},
#  30: {'mean fractal dimension': 0.06197,
#       'smoothness error': 0.006248,
#       'texture error': 1.466,
#       'worst fractal dimension': 0.09782},
#  31: {'mean fractal dimension': 0.07799,
#       'smoothness error': 0.005551,
#       'texture error': 1.03,
#       'worst fractal dimension': 0.1402},
#  32: {'mean fractal dimension': 0.06382,
#       'smoothness error': 0.008268,
#       'texture error': 1.398,
#       'worst fractal dimension': 0.08482},
#  33: {'mean fractal dimension': 0.06261,
#       'smoothness error': 0.005015,
#       'texture error': 0.6062,
#       'worst fractal dimension': 0.1123},
#  34: {'mean fractal dimension': 0.06515,
#       'smoothness error': 0.004185,
#       'texture error': 0.6857,
#       'worst fractal dimension': 0.1233},
#  35: {'mean fractal dimension': 0.05656,
#       'smoothness error': 0.005776,
#       'texture error': 0.9197,
#       'worst fractal dimension': 0.08633},
#  36: {'mean fractal dimension': 0.06125,
#       'smoothness error': 0.005878,
#       'texture error': 1.019,
#       'worst fractal dimension': 0.1014},
#  37: {'mean fractal dimension': 0.05863,
#       'smoothness error': 0.004352,
#       'texture error': 2.342,
#       'worst fractal dimension': 0.06169},
#  38: {'mean fractal dimension': 0.05504,
#       'smoothness error': 0.006883,
#       'texture error': 2.188,
#       'worst fractal dimension': 0.05504},
#  39: {'mean fractal dimension': 0.06419,
#       'smoothness error': 0.005367,
#       'texture error': 0.5914,
#       'worst fractal dimension': 0.1071},
#  40: {'mean fractal dimension': 0.05587,
#       'smoothness error': 0.00328,
#       'texture error': 0.8265,
#       'worst fractal dimension': 0.07146},
#  41: {'mean fractal dimension': 0.0687,
#       'smoothness error': 0.008064,
#       'texture error': 1.428,
#       'worst fractal dimension': 0.09606},
#  42: {'mean fractal dimension': 0.06343,
#       'smoothness error': 0.006548,
#       'texture error': 1.666,
#       'worst fractal dimension': 0.1038},
#  43: {'mean fractal dimension': 0.06782,
#       'smoothness error': 0.005072,
#       'texture error': 0.8249,
#       'worst fractal dimension': 0.1027},
#  44: {'mean fractal dimension': 0.06177,
#       'smoothness error': 0.00335,
#       'texture error': 0.6123,
#       'worst fractal dimension': 0.09618},
#  45: {'mean fractal dimension': 0.06049,
#       'smoothness error': 0.006294,
#       'texture error': 0.6633,
#       'worst fractal dimension': 0.09185},
#  46: {'mean fractal dimension': 0.06503,
#       'smoothness error': 0.008968,
#       'texture error': 0.9567,
#       'worst fractal dimension': 0.07409},
#  47: {'mean fractal dimension': 0.06777,
#       'smoothness error': 0.006532,
#       'texture error': 0.8937,
#       'worst fractal dimension': 0.1179},
#  48: {'mean fractal dimension': 0.06043,
#       'smoothness error': 0.005488,
#       'texture error': 0.7294,
#       'worst fractal dimension': 0.08301},
#  49: {'mean fractal dimension': 0.05718,
#       'smoothness error': 0.004455,
#       'texture error': 1.353,
#       'worst fractal dimension': 0.06917},
#  50: {'mean fractal dimension': 0.05888,
#       'smoothness error': 0.005857,
#       'texture error': 1.21,
#       'worst fractal dimension': 0.06563},
#  51: {'mean fractal dimension': 0.05953,
#       'smoothness error': 0.004477,
#       'texture error': 0.9234,
#       'worst fractal dimension': 0.08025},
#  52: {'mean fractal dimension': 0.0611,
#       'smoothness error': 0.00721,
#       'texture error': 0.6329,
#       'worst fractal dimension': 0.07408},
#  53: {'mean fractal dimension': 0.0631,
#       'smoothness error': 0.003899,
#       'texture error': 1.593,
#       'worst fractal dimension': 0.07987},
#  54: {'mean fractal dimension': 0.05684,
#       'smoothness error': 0.004675,
#       'texture error': 0.8339,
#       'worst fractal dimension': 0.07873},
#  55: {'mean fractal dimension': 0.05907,
#       'smoothness error': 0.008328,
#       'texture error': 0.9591,
#       'worst fractal dimension': 0.07036},
#  56: {'mean fractal dimension': 0.05961,
#       'smoothness error': 0.006458,
#       'texture error': 1.193,
#       'worst fractal dimension': 0.08294},
#  57: {'mean fractal dimension': 0.06758,
#       'smoothness error': 0.003659,
#       'texture error': 1.15,
#       'worst fractal dimension': 0.1094},
#  58: {'mean fractal dimension': 0.05501,
#       'smoothness error': 0.007491,
#       'texture error': 1.214,
#       'worst fractal dimension': 0.06289},
#  59: {'mean fractal dimension': 0.07187,
#       'smoothness error': 0.01011,
#       'texture error': 0.5796,
#       'worst fractal dimension': 0.09026},
#  60: {'mean fractal dimension': 0.0696,
#       'smoothness error': 0.007514,
#       'texture error': 1.441,
#       'worst fractal dimension': 0.0802},
#  61: {'mean fractal dimension': 0.06757,
#       'smoothness error': 0.01193,
#       'texture error': 2.067,
#       'worst fractal dimension': 0.07712},
#  62: {'mean fractal dimension': 0.07292,
#       'smoothness error': 0.009407,
#       'texture error': 1.268,
#       'worst fractal dimension': 0.1132},
#  63: {'mean fractal dimension': 0.06963,
#       'smoothness error': 0.008738,
#       'texture error': 2.265,
#       'worst fractal dimension': 0.0849},
#  64: {'mean fractal dimension': 0.0659,
#       'smoothness error': 0.007781,
#       'texture error': 1.178,
#       'worst fractal dimension': 0.1031},
#  65: {'mean fractal dimension': 0.06654,
#       'smoothness error': 0.006703,
#       'texture error': 1.281,
#       'worst fractal dimension': 0.08911},
#  66: {'mean fractal dimension': 0.06899,
#       'smoothness error': 0.01052,
#       'texture error': 2.011,
#       'worst fractal dimension': 0.09211},
#  67: {'mean fractal dimension': 0.05667,
#       'smoothness error': 0.009282,
#       'texture error': 0.9429,
#       'worst fractal dimension': 0.06641},
#  68: {'mean fractal dimension': 0.08046,
#       'smoothness error': 0.009549,
#       'texture error': 1.194,
#       'worst fractal dimension': 0.1175},
#  69: {'mean fractal dimension': 0.05653,
#       'smoothness error': 0.007962,
#       'texture error': 0.8732,
#       'worst fractal dimension': 0.0641},
#  70: {'mean fractal dimension': 0.05461,
#       'smoothness error': 0.004444,
#       'texture error': 0.7975,
#       'worst fractal dimension': 0.06589},
#  71: {'mean fractal dimension': 0.0898,
#       'smoothness error': 0.01721,
#       'texture error': 0.8522,
#       'worst fractal dimension': 0.1084},
#  72: {'mean fractal dimension': 0.06487,
#       'smoothness error': 0.00582,
#       'texture error': 1.041,
#       'worst fractal dimension': 0.1339},
#  73: {'mean fractal dimension': 0.06566,
#       'smoothness error': 0.004717,
#       'texture error': 0.6205,
#       'worst fractal dimension': 0.103},
#  74: {'mean fractal dimension': 0.05914,
#       'smoothness error': 0.004854,
#       'texture error': 1.025,
#       'worst fractal dimension': 0.07609},
#  75: {'mean fractal dimension': 0.05391,
#       'smoothness error': 0.01082,
#       'texture error': 1.016,
#       'worst fractal dimension': 0.06387},
#  76: {'mean fractal dimension': 0.06641,
#       'smoothness error': 0.0134,
#       'texture error': 1.014,
#       'worst fractal dimension': 0.07191},
#  77: {'mean fractal dimension': 0.06673,
#       'smoothness error': 0.00794,
#       'texture error': 0.5505,
#       'worst fractal dimension': 0.1108},
#  78: {'mean fractal dimension': 0.08142,
#       'smoothness error': 0.01038,
#       'texture error': 1.885,
#       'worst fractal dimension': 0.09964},
#  79: {'mean fractal dimension': 0.05997,
#       'smoothness error': 0.005293,
#       'texture error': 1.095,
#       'worst fractal dimension': 0.07918},
#  80: {'mean fractal dimension': 0.07005,
#       'smoothness error': 0.01037,
#       'texture error': 2.174,
#       'worst fractal dimension': 0.08851},
#  81: {'mean fractal dimension': 0.06902,
#       'smoothness error': 0.006794,
#       'texture error': 1.016,
#       'worst fractal dimension': 0.1016},
#  82: {'mean fractal dimension': 0.06782,
#       'smoothness error': 0.008166,
#       'texture error': 1.474,
#       'worst fractal dimension': 0.1051},
#  83: {'mean fractal dimension': 0.07224,
#       'smoothness error': 0.007545,
#       'texture error': 2.91,
#       'worst fractal dimension': 0.09203},
#  84: {'mean fractal dimension': 0.05968,
#       'smoothness error': 0.005969,
#       'texture error': 1.255,
#       'worst fractal dimension': 0.07924},
#  85: {'mean fractal dimension': 0.06022,
#       'smoothness error': 0.006471,
#       'texture error': 1.475,
#       'worst fractal dimension': 0.08579},
#  86: {'mean fractal dimension': 0.05636,
#       'smoothness error': 0.009369,
#       'texture error': 2.22,
#       'worst fractal dimension': 0.06846},
#  87: {'mean fractal dimension': 0.05629,
#       'smoothness error': 0.003872,
#       'texture error': 0.6636,
#       'worst fractal dimension': 0.09288},
#  88: {'mean fractal dimension': 0.06404,
#       'smoothness error': 0.007112,
#       'texture error': 1.502,
#       'worst fractal dimension': 0.09261},
#  89: {'mean fractal dimension': 0.06346,
#       'smoothness error': 0.005508,
#       'texture error': 0.7372,
#       'worst fractal dimension': 0.08473},
#  90: {'mean fractal dimension': 0.05866,
#       'smoothness error': 0.004868,
#       'texture error': 1.111,
#       'worst fractal dimension': 0.07246},
#  91: {'mean fractal dimension': 0.06097,
#       'smoothness error': 0.009882,
#       'texture error': 0.8413,
#       'worst fractal dimension': 0.06828},
#  92: {'mean fractal dimension': 0.05318,
#       'smoothness error': 0.004481,
#       'texture error': 1.153,
#       'worst fractal dimension': 0.06206},
#  93: {'mean fractal dimension': 0.0571,
#       'smoothness error': 0.005884,
#       'texture error': 1.373,
#       'worst fractal dimension': 0.06603},
#  94: {'mean fractal dimension': 0.06284,
#       'smoothness error': 0.00925,
#       'texture error': 0.9644,
#       'worst fractal dimension': 0.08234},
#  95: {'mean fractal dimension': 0.05649,
#       'smoothness error': 0.006016,
#       'texture error': 1.509,
#       'worst fractal dimension': 0.08368},
#  96: {'mean fractal dimension': 0.06635,
#       'smoothness error': 0.005433,
#       'texture error': 1.511,
#       'worst fractal dimension': 0.07376},
#  97: {'mean fractal dimension': 0.0689,
#       'smoothness error': 0.01113,
#       'texture error': 2.043,
#       'worst fractal dimension': 0.08988},
#  98: {'mean fractal dimension': 0.06582,
#       'smoothness error': 0.006153,
#       'texture error': 0.5391,
#       'worst fractal dimension': 0.08756},
#  99: {'mean fractal dimension': 0.0639,
#       'smoothness error': 0.008005,
#       'texture error': 1.851,
#       'worst fractal dimension': 0.09353},
#  100: {'mean fractal dimension': 0.05871,
#        'smoothness error': 0.005872,
#        'texture error': 1.29,
#        'worst fractal dimension': 0.07397},
#  101: {'mean fractal dimension': 0.07818,
#        'smoothness error': 0.01019,
#        'texture error': 1.508,
#        'worst fractal dimension': 0.09382},
#  102: {'mean fractal dimension': 0.05677,
#        'smoothness error': 0.00508,
#        'texture error': 1.571,
#        'worst fractal dimension': 0.06878},
#  103: {'mean fractal dimension': 0.06322,
#        'smoothness error': 0.009058,
#        'texture error': 1.222,
#        'worst fractal dimension': 0.0849},
#  104: {'mean fractal dimension': 0.06481,
#        'smoothness error': 0.007595,
#        'texture error': 1.534,
#        'worst fractal dimension': 0.07552},
#  105: {'mean fractal dimension': 0.07692,
#        'smoothness error': 0.007162,
#        'texture error': 0.9238,
#        'worst fractal dimension': 0.1405},
#  106: {'mean fractal dimension': 0.0652,
#        'smoothness error': 0.00854,
#        'texture error': 1.657,
#        'worst fractal dimension': 0.09097},
#  107: {'mean fractal dimension': 0.06066,
#        'smoothness error': 0.003457,
#        'texture error': 0.8944,
#        'worst fractal dimension': 0.07185},
#  108: {'mean fractal dimension': 0.07039,
#        'smoothness error': 0.006515,
#        'texture error': 1.545,
#        'worst fractal dimension': 0.09789},
#  109: {'mean fractal dimension': 0.06529,
#        'smoothness error': 0.009113,
#        'texture error': 0.9861,
#        'worst fractal dimension': 0.08832},
#  110: {'mean fractal dimension': 0.07065,
#        'smoothness error': 0.01385,
#        'texture error': 1.424,
#        'worst fractal dimension': 0.08468},
#  111: {'mean fractal dimension': 0.0707,
#        'smoothness error': 0.01291,
#        'texture error': 1.803,
#        'worst fractal dimension': 0.08486},
#  112: {'mean fractal dimension': 0.07769,
#        'smoothness error': 0.005298,
#        'texture error': 1.49,
#        'worst fractal dimension': 0.1082},
#  113: {'mean fractal dimension': 0.07782,
#        'smoothness error': 0.01188,
#        'texture error': 1.86,
#        'worst fractal dimension': 0.09026},
#  114: {'mean fractal dimension': 0.07633,
#        'smoothness error': 0.008261,
#        'texture error': 0.5864,
#        'worst fractal dimension': 0.1017},
#  115: {'mean fractal dimension': 0.06194,
#        'smoothness error': 0.007803,
#        'texture error': 0.9227,
#        'worst fractal dimension': 0.08541},
#  116: {'mean fractal dimension': 0.07163,
#        'smoothness error': 0.01835,
#        'texture error': 0.9789,
#        'worst fractal dimension': 0.07722},
#  117: {'mean fractal dimension': 0.06768,
#        'smoothness error': 0.006985,
#        'texture error': 0.9489,
#        'worst fractal dimension': 0.1065},
#  118: {'mean fractal dimension': 0.07331,
#        'smoothness error': 0.008699,
#        'texture error': 1.072,
#        'worst fractal dimension': 0.1252},
#  119: {'mean fractal dimension': 0.05025,
#        'smoothness error': 0.004024,
#        'texture error': 1.214,
#        'worst fractal dimension': 0.06111},
#  120: {'mean fractal dimension': 0.06113,
#        'smoothness error': 0.00604,
#        'texture error': 0.4607,
#        'worst fractal dimension': 0.08523},
#  121: {'mean fractal dimension': 0.06213,
#        'smoothness error': 0.008102,
#        'texture error': 1.581,
#        'worst fractal dimension': 0.08456},
#  122: {'mean fractal dimension': 0.06877,
#        'smoothness error': 0.02333,
#        'texture error': 3.12,
#        'worst fractal dimension': 0.08009},
#  123: {'mean fractal dimension': 0.06402,
#        'smoothness error': 0.003818,
#        'texture error': 0.857,
#        'worst fractal dimension': 0.08006},
#  124: {'mean fractal dimension': 0.05823,
#        'smoothness error': 0.005919,
#        'texture error': 1.14,
#        'worst fractal dimension': 0.07628},
#  125: {'mean fractal dimension': 0.0589,
#        'smoothness error': 0.004599,
#        'texture error': 0.8561,
#        'worst fractal dimension': 0.07182},
#  126: {'mean fractal dimension': 0.0613,
#        'smoothness error': 0.004088,
#        'texture error': 1.005,
#        'worst fractal dimension': 0.079},
#  127: {'mean fractal dimension': 0.05044,
#        'smoothness error': 0.004428,
#        'texture error': 1.342,
#        'worst fractal dimension': 0.06541},
#  128: {'mean fractal dimension': 0.06467,
#        'smoothness error': 0.009006,
#        'texture error': 1.068,
#        'worst fractal dimension': 0.07779},
#  129: {'mean fractal dimension': 0.06113,
#        'smoothness error': 0.005033,
#        'texture error': 1.199,
#        'worst fractal dimension': 0.08465},
#  130: {'mean fractal dimension': 0.06471,
#        'smoothness error': 0.006773,
#        'texture error': 0.8163,
#        'worst fractal dimension': 0.09241},
#  131: {'mean fractal dimension': 0.05796,
#        'smoothness error': 0.00624,
#        'texture error': 0.7859,
#        'worst fractal dimension': 0.08019},
#  132: {'mean fractal dimension': 0.05891,
#        'smoothness error': 0.004877,
#        'texture error': 1.265,
#        'worst fractal dimension': 0.07619},
#  133: {'mean fractal dimension': 0.05723,
#        'smoothness error': 0.005217,
#        'texture error': 0.8155,
#        'worst fractal dimension': 0.07071},
#  134: {'mean fractal dimension': 0.05727,
#        'smoothness error': 0.006001,
#        'texture error': 1.202,
#        'worst fractal dimension': 0.0761},
#  135: {'mean fractal dimension': 0.06065,
#        'smoothness error': 0.007499,
#        'texture error': 1.38,
#        'worst fractal dimension': 0.08067},
#  136: {'mean fractal dimension': 0.05945,
#        'smoothness error': 0.006578,
#        'texture error': 2.508,
#        'worst fractal dimension': 0.07343},
#  137: {'mean fractal dimension': 0.05865,
#        'smoothness error': 0.005133,
#        'texture error': 0.9938,
#        'worst fractal dimension': 0.06765},
#  138: {'mean fractal dimension': 0.06216,
#        'smoothness error': 0.01,
#        'texture error': 1.452,
#        'worst fractal dimension': 0.07147},
#  139: {'mean fractal dimension': 0.06072,
#        'smoothness error': 0.01127,
#        'texture error': 1.343,
#        'worst fractal dimension': 0.06784},
#  140: {'mean fractal dimension': 0.06422,
#        'smoothness error': 0.00604,
#        'texture error': 0.496,
#        'worst fractal dimension': 0.08151},
#  141: {'mean fractal dimension': 0.06248,
#        'smoothness error': 0.00677,
#        'texture error': 1.332,
#        'worst fractal dimension': 0.08158},
#  142: {'mean fractal dimension': 0.06562,
#        'smoothness error': 0.006664,
#        'texture error': 1.908,
#        'worst fractal dimension': 0.08096},
#  143: {'mean fractal dimension': 0.06235,
#        'smoothness error': 0.005324,
#        'texture error': 0.7712,
#        'worst fractal dimension': 0.08118},
#  144: {'mean fractal dimension': 0.05688,
#        'smoothness error': 0.006547,
#        'texture error': 1.239,
#        'worst fractal dimension': 0.06769},
#  145: {'mean fractal dimension': 0.07839,
#        'smoothness error': 0.01017,
#        'texture error': 0.6538,
#        'worst fractal dimension': 0.1036},
#  146: {'mean fractal dimension': 0.07371,
#        'smoothness error': 0.005427,
#        'texture error': 1.426,
#        'worst fractal dimension': 0.103},
#  147: {'mean fractal dimension': 0.06493,
#        'smoothness error': 0.00579,
#        'texture error': 1.909,
#        'worst fractal dimension': 0.09218},
#  148: {'mean fractal dimension': 0.06081,
#        'smoothness error': 0.005706,
#        'texture error': 0.7394,
#        'worst fractal dimension': 0.07683},
#  149: {'mean fractal dimension': 0.0558,
#        'smoothness error': 0.002838,
#        'texture error': 0.7574,
#        'worst fractal dimension': 0.07014},
#  150: {'mean fractal dimension': 0.06087,
#        'smoothness error': 0.007017,
#        'texture error': 1.322,
#        'worst fractal dimension': 0.06435},
#  151: {'mean fractal dimension': 0.08261,
#        'smoothness error': 0.01243,
#        'texture error': 1.962,
#        'worst fractal dimension': 0.1486},
#  152: {'mean fractal dimension': 0.09296,
#        'smoothness error': 0.01097,
#        'texture error': 2.664,
#        'worst fractal dimension': 0.1259},
#  153: {'mean fractal dimension': 0.06105,
#        'smoothness error': 0.009019,
#        'texture error': 0.7815,
#        'worst fractal dimension': 0.06772},
#  154: {'mean fractal dimension': 0.06207,
#        'smoothness error': 0.008584,
#        'texture error': 0.7927,
#        'worst fractal dimension': 0.08633},
#  155: {'mean fractal dimension': 0.06228,
#        'smoothness error': 0.005518,
#        'texture error': 0.9823,
#        'worst fractal dimension': 0.08132},
#  156: {'mean fractal dimension': 0.06166,
#        'smoothness error': 0.009037,
#        'texture error': 1.4,
#        'worst fractal dimension': 0.07738},
#  157: {'mean fractal dimension': 0.05268,
#        'smoothness error': 0.003443,
#        'texture error': 2.06,
#        'worst fractal dimension': 0.05972},
#  158: {'mean fractal dimension': 0.05907,
#        'smoothness error': 0.005528,
#        'texture error': 0.7285,
#        'worst fractal dimension': 0.07898},
#  159: {'mean fractal dimension': 0.05743,
#        'smoothness error': 0.006142,
#        'texture error': 0.7614,
#        'worst fractal dimension': 0.07685},
#  160: {'mean fractal dimension': 0.06453,
#        'smoothness error': 0.009433,
#        'texture error': 1.693,
#        'worst fractal dimension': 0.07987},
#  161: {'mean fractal dimension': 0.05176,
#        'smoothness error': 0.009406,
#        'texture error': 0.6336,
#        'worst fractal dimension': 0.06251},
#  162: {'mean fractal dimension': 0.06082,
#        'smoothness error': 0.004057,
#        'texture error': 1.048,
#        'worst fractal dimension': 0.09223},
#  163: {'mean fractal dimension': 0.06761,
#        'smoothness error': 0.01134,
#        'texture error': 1.656,
#        'worst fractal dimension': 0.09082},
#  164: {'mean fractal dimension': 0.05553,
#        'smoothness error': 0.00491,
#        'texture error': 0.8561,
#        'worst fractal dimension': 0.09187},
#  165: {'mean fractal dimension': 0.05266,
#        'smoothness error': 0.003634,
#        'texture error': 1.065,
#        'worst fractal dimension': 0.06085},
#  166: {'mean fractal dimension': 0.064,
#        'smoothness error': 0.007809,
#        'texture error': 0.4064,
#        'worst fractal dimension': 0.07699},
#  167: {'mean fractal dimension': 0.05534,
#        'smoothness error': 0.006123,
#        'texture error': 1.391,
#        'worst fractal dimension': 0.07228},
#  168: {'mean fractal dimension': 0.06365,
#        'smoothness error': 0.006174,
#        'texture error': 1.41,
#        'worst fractal dimension': 0.093},
#  169: {'mean fractal dimension': 0.0565,
#        'smoothness error': 0.00508,
#        'texture error': 1.217,
#        'worst fractal dimension': 0.06428},
#  170: {'mean fractal dimension': 0.05955,
#        'smoothness error': 0.008045,
#        'texture error': 0.6656,
#        'worst fractal dimension': 0.06771},
#  171: {'mean fractal dimension': 0.05671,
#        'smoothness error': 0.006003,
#        'texture error': 1.147,
#        'worst fractal dimension': 0.07371},
#  172: {'mean fractal dimension': 0.07069,
#        'smoothness error': 0.005393,
#        'texture error': 0.6583,
#        'worst fractal dimension': 0.101},
#  173: {'mean fractal dimension': 0.06669,
#        'smoothness error': 0.01496,
#        'texture error': 1.805,
#        'worst fractal dimension': 0.07313},
#  174: {'mean fractal dimension': 0.05975,
#        'smoothness error': 0.008713,
#        'texture error': 1.925,
#        'worst fractal dimension': 0.06164},
#  175: {'mean fractal dimension': 0.06724,
#        'smoothness error': 0.009172,
#        'texture error': 0.7873,
#        'worst fractal dimension': 0.07848},
#  176: {'mean fractal dimension': 0.08116,
#        'smoothness error': 0.01286,
#        'texture error': 2.261,
#        'worst fractal dimension': 0.1162},
#  177: {'mean fractal dimension': 0.06323,
#        'smoothness error': 0.006627,
#        'texture error': 1.284,
#        'worst fractal dimension': 0.09519},
#  178: {'mean fractal dimension': 0.05234,
#        'smoothness error': 0.003418,
#        'texture error': 1.142,
#        'worst fractal dimension': 0.05843},
#  179: {'mean fractal dimension': 0.06133,
#        'smoothness error': 0.008534,
#        'texture error': 0.9899,
#        'worst fractal dimension': 0.07319},
#  180: {'mean fractal dimension': 0.0577,
#        'smoothness error': 0.004631,
#        'texture error': 1.481,
#        'worst fractal dimension': 0.08082},
#  181: {'mean fractal dimension': 0.07398,
#        'smoothness error': 0.004253,
#        'texture error': 0.7629,
#        'worst fractal dimension': 0.1284},
#  182: {'mean fractal dimension': 0.05549,
#        'smoothness error': 0.004626,
#        'texture error': 1.15,
#        'worst fractal dimension': 0.08631},
#  183: {'mean fractal dimension': 0.06217,
#        'smoothness error': 0.007356,
#        'texture error': 1.108,
#        'worst fractal dimension': 0.07427},
#  184: {'mean fractal dimension': 0.06317,
#        'smoothness error': 0.00329,
#        'texture error': 0.4956,
#        'worst fractal dimension': 0.09772},
#  185: {'mean fractal dimension': 0.06048,
#        'smoothness error': 0.01439,
#        'texture error': 1.268,
#        'worst fractal dimension': 0.07697},
#  186: {'mean fractal dimension': 0.05425,
#        'smoothness error': 0.002866,
#        'texture error': 0.4757,
#        'worst fractal dimension': 0.06938},
#  187: {'mean fractal dimension': 0.06095,
#        'smoothness error': 0.006905,
#        'texture error': 0.7655,
#        'worst fractal dimension': 0.07097},
#  188: {'mean fractal dimension': 0.0578,
#        'smoothness error': 0.007831,
#        'texture error': 1.926,
#        'worst fractal dimension': 0.06576},
#  189: {'mean fractal dimension': 0.05474,
#        'smoothness error': 0.005996,
#        'texture error': 0.8355,
#        'worst fractal dimension': 0.06306},
#  190: {'mean fractal dimension': 0.07542,
#        'smoothness error': 0.00797,
#        'texture error': 2.11,
#        'worst fractal dimension': 0.1446},
#  191: {'mean fractal dimension': 0.06287,
#        'smoothness error': 0.004571,
#        'texture error': 1.748,
#        'worst fractal dimension': 0.06871},
#  192: {'mean fractal dimension': 0.06447,
#        'smoothness error': 0.001713,
#        'texture error': 4.885,
#        'worst fractal dimension': 0.06559},
#  193: {'mean fractal dimension': 0.06937,
#        'smoothness error': 0.009098,
#        'texture error': 1.809,
#        'worst fractal dimension': 0.1205},
#  194: {'mean fractal dimension': 0.06672,
#        'smoothness error': 0.008081,
#        'texture error': 0.9622,
#        'worst fractal dimension': 0.08701},
#  195: {'mean fractal dimension': 0.05667,
#        'smoothness error': 0.005298,
#        'texture error': 0.9086,
#        'worst fractal dimension': 0.06949},
#  196: {'mean fractal dimension': 0.06877,
#        'smoothness error': 0.0138,
#        'texture error': 2.112,
#        'worst fractal dimension': 0.09333},
#  197: {'mean fractal dimension': 0.0534,
#        'smoothness error': 0.00553,
#        'texture error': 1.305,
#        'worst fractal dimension': 0.06558},
#  198: {'mean fractal dimension': 0.05529,
#        'smoothness error': 0.005524,
#        'texture error': 1.073,
#        'worst fractal dimension': 0.09221},
#  199: {'mean fractal dimension': 0.06466,
#        'smoothness error': 0.004044,
#        'texture error': 0.6509,
#        'worst fractal dimension': 0.1013},
#  200: {'mean fractal dimension': 0.06013,
#        'smoothness error': 0.007514,
#        'texture error': 1.326,
#        'worst fractal dimension': 0.08174},
#  201: {'mean fractal dimension': 0.05491,
#        'smoothness error': 0.00609,
#        'texture error': 0.8282,
#        'worst fractal dimension': 0.07867},
#  202: {'mean fractal dimension': 0.06229,
#        'smoothness error': 0.009327,
#        'texture error': 1.56,
#        'worst fractal dimension': 0.08762},
#  203: {'mean fractal dimension': 0.07421,
#        'smoothness error': 0.008824,
#        'texture error': 1.93,
#        'worst fractal dimension': 0.1086},
#  204: {'mean fractal dimension': 0.06373,
#        'smoothness error': 0.006953,
#        'texture error': 1.044,
#        'worst fractal dimension': 0.0875},
#  205: {'mean fractal dimension': 0.05986,
#        'smoothness error': 0.005472,
#        'texture error': 0.3621,
#        'worst fractal dimension': 0.0974},
#  206: {'mean fractal dimension': 0.06285,
#        'smoothness error': 0.009719,
#        'texture error': 1.342,
#        'worst fractal dimension': 0.0738},
#  207: {'mean fractal dimension': 0.05223,
#        'smoothness error': 0.005038,
#        'texture error': 0.8554,
#        'worst fractal dimension': 0.06469},
#  208: {'mean fractal dimension': 0.0731,
#        'smoothness error': 0.005251,
#        'texture error': 0.9223,
#        'worst fractal dimension': 0.1076},
#  209: {'mean fractal dimension': 0.05526,
#        'smoothness error': 0.004291,
#        'texture error': 0.3628,
#        'worst fractal dimension': 0.07474},
#  210: {'mean fractal dimension': 0.05024,
#        'smoothness error': 0.008124,
#        'texture error': 1.48,
#        'worst fractal dimension': 0.05865},
#  211: {'mean fractal dimension': 0.06057,
#        'smoothness error': 0.005517,
#        'texture error': 0.8652,
#        'worst fractal dimension': 0.07993},
#  212: {'mean fractal dimension': 0.05525,
#        'smoothness error': 0.01345,
#        'texture error': 1.476,
#        'worst fractal dimension': 0.05525},
#  213: {'mean fractal dimension': 0.05866,
#        'smoothness error': 0.03113,
#        'texture error': 1.667,
#        'worst fractal dimension': 0.06818},
#  214: {'mean fractal dimension': 0.06433,
#        'smoothness error': 0.01088,
#        'texture error': 1.845,
#        'worst fractal dimension': 0.1026},
#  215: {'mean fractal dimension': 0.06916,
#        'smoothness error': 0.00596,
#        'texture error': 1.194,
#        'worst fractal dimension': 0.1059},
#  216: {'mean fractal dimension': 0.06314,
#        'smoothness error': 0.008872,
#        'texture error': 1.563,
#        'worst fractal dimension': 0.08365},
#  217: {'mean fractal dimension': 0.06315,
#        'smoothness error': 0.00468,
#        'texture error': 1.922,
#        'worst fractal dimension': 0.07809},
#  218: {'mean fractal dimension': 0.05581,
#        'smoothness error': 0.006804,
#        'texture error': 1.186,
#        'worst fractal dimension': 0.08255},
#  219: {'mean fractal dimension': 0.05313,
#        'smoothness error': 0.005539,
#        'texture error': 1.321,
#        'worst fractal dimension': 0.07568},
#  220: {'mean fractal dimension': 0.06344,
#        'smoothness error': 0.004133,
#        'texture error': 0.4336,
#        'worst fractal dimension': 0.08718},
#  221: {'mean fractal dimension': 0.06303,
#        'smoothness error': 0.005851,
#        'texture error': 0.4981,
#        'worst fractal dimension': 0.08177},
#  222: {'mean fractal dimension': 0.06908,
#        'smoothness error': 0.007899,
#        'texture error': 1.217,
#        'worst fractal dimension': 0.08797},
#  223: {'mean fractal dimension': 0.06303,
#        'smoothness error': 0.004766,
#        'texture error': 0.9209,
#        'worst fractal dimension': 0.1064},
#  224: {'mean fractal dimension': 0.05674,
#        'smoothness error': 0.006032,
#        'texture error': 0.8907,
#        'worst fractal dimension': 0.07623},
#  225: {'mean fractal dimension': 0.05448,
#        'smoothness error': 0.007089,
#        'texture error': 0.8121,
#        'worst fractal dimension': 0.06072},
#  226: {'mean fractal dimension': 0.0645,
#        'smoothness error': 0.006513,
#        'texture error': 0.9027,
#        'worst fractal dimension': 0.08269},
#  227: {'mean fractal dimension': 0.05907,
#        'smoothness error': 0.004119,
#        'texture error': 0.4966,
#        'worst fractal dimension': 0.08362},
#  228: {'mean fractal dimension': 0.06019,
#        'smoothness error': 0.005169,
#        'texture error': 1.066,
#        'worst fractal dimension': 0.09585},
#  229: {'mean fractal dimension': 0.07254,
#        'smoothness error': 0.006983,
#        'texture error': 1.069,
#        'worst fractal dimension': 0.1243},
#  230: {'mean fractal dimension': 0.06325,
#        'smoothness error': 0.005532,
#        'texture error': 0.679,
#        'worst fractal dimension': 0.09061},
#  231: {'mean fractal dimension': 0.05628,
#        'smoothness error': 0.003653,
#        'texture error': 0.8927,
#        'worst fractal dimension': 0.07087},
#  232: {'mean fractal dimension': 0.05828,
#        'smoothness error': 0.004359,
#        'texture error': 1.647,
#        'worst fractal dimension': 0.07307},
#  233: {'mean fractal dimension': 0.05592,
#        'smoothness error': 0.00502,
#        'texture error': 1.189,
#        'worst fractal dimension': 0.08328},
#  234: {'mean fractal dimension': 0.06403,
#        'smoothness error': 0.01164,
#        'texture error': 0.8301,
#        'worst fractal dimension': 0.08178},
#  235: {'mean fractal dimension': 0.05835,
#        'smoothness error': 0.007389,
#        'texture error': 1.503,
#        'worst fractal dimension': 0.07617},
#  236: {'mean fractal dimension': 0.06309,
#        'smoothness error': 0.006428,
#        'texture error': 0.9635,
#        'worst fractal dimension': 0.08677},
#  237: {'mean fractal dimension': 0.05177,
#        'smoothness error': 0.007959,
#        'texture error': 1.041,
#        'worst fractal dimension': 0.07127},
#  238: {'mean fractal dimension': 0.06129,
#        'smoothness error': 0.006307,
#        'texture error': 2.324,
#        'worst fractal dimension': 0.07796},
#  239: {'mean fractal dimension': 0.05966,
#        'smoothness error': 0.00486,
#        'texture error': 0.8561,
#        'worst fractal dimension': 0.08496},
#  240: {'mean fractal dimension': 0.0566,
#        'smoothness error': 0.00647,
#        'texture error': 0.6612,
#        'worst fractal dimension': 0.0651},
#  241: {'mean fractal dimension': 0.05754,
#        'smoothness error': 0.003265,
#        'texture error': 0.6745,
#        'worst fractal dimension': 0.06783},
#  242: {'mean fractal dimension': 0.07669,
#        'smoothness error': 0.006663,
#        'texture error': 1.642,
#        'worst fractal dimension': 0.1297},
#  243: {'mean fractal dimension': 0.05429,
#        'smoothness error': 0.004351,
#        'texture error': 1.057,
#        'worst fractal dimension': 0.06321},
#  244: {'mean fractal dimension': 0.06,
#        'smoothness error': 0.01061,
#        'texture error': 1.802,
#        'worst fractal dimension': 0.07614},
#  245: {'mean fractal dimension': 0.0644,
#        'smoothness error': 0.01604,
#        'texture error': 2.612,
#        'worst fractal dimension': 0.07748},
#  246: {'mean fractal dimension': 0.05635,
#        'smoothness error': 0.006261,
#        'texture error': 1.601,
#        'worst fractal dimension': 0.07198},
#  247: {'mean fractal dimension': 0.06409,
#        'smoothness error': 0.005501,
#        'texture error': 0.4402,
#        'worst fractal dimension': 0.1178},
#  248: {'mean fractal dimension': 0.06329,
#        'smoothness error': 0.007189,
#        'texture error': 1.493,
#        'worst fractal dimension': 0.08147},
#  249: {'mean fractal dimension': 0.06168,
#        'smoothness error': 0.006662,
#        'texture error': 1.038,
#        'worst fractal dimension': 0.07809},
#  250: {'mean fractal dimension': 0.05898,
#        'smoothness error': 0.005283,
#        'texture error': 0.8208,
#        'worst fractal dimension': 0.07849},
#  251: {'mean fractal dimension': 0.05934,
#        'smoothness error': 0.00638,
#        'texture error': 0.8429,
#        'worst fractal dimension': 0.06487},
#  252: {'mean fractal dimension': 0.06697,
#        'smoothness error': 0.008482,
#        'texture error': 0.78,
#        'worst fractal dimension': 0.1297},
#  253: {'mean fractal dimension': 0.05613,
#        'smoothness error': 0.004757,
#        'texture error': 0.8568,
#        'worst fractal dimension': 0.08113},
#  254: {'mean fractal dimension': 0.05647,
#        'smoothness error': 0.004649,
#        'texture error': 0.6342,
#        'worst fractal dimension': 0.0895},
#  255: {'mean fractal dimension': 0.0613,
#        'smoothness error': 0.006351,
#        'texture error': 0.8098,
#        'worst fractal dimension': 0.07957},
#  256: {'mean fractal dimension': 0.06232,
#        'smoothness error': 0.006356,
#        'texture error': 1.199,
#        'worst fractal dimension': 0.1005},
#  257: {'mean fractal dimension': 0.07596,
#        'smoothness error': 0.01015,
#        'texture error': 1.059,
#        'worst fractal dimension': 0.1191},
#  258: {'mean fractal dimension': 0.08104,
#        'smoothness error': 0.01236,
#        'texture error': 2.454,
#        'worst fractal dimension': 0.1019},
#  259: {'mean fractal dimension': 0.0665,
#        'smoothness error': 0.005345,
#        'texture error': 1.278,
#        'worst fractal dimension': 0.1204},
#  260: {'mean fractal dimension': 0.05572,
#        'smoothness error': 0.005043,
#        'texture error': 1.033,
#        'worst fractal dimension': 0.07999},
#  261: {'mean fractal dimension': 0.05307,
#        'smoothness error': 0.005726,
#        'texture error': 1.317,
#        'worst fractal dimension': 0.06515},
#  262: {'mean fractal dimension': 0.05464,
#        'smoothness error': 0.006717,
#        'texture error': 1.633,
#        'worst fractal dimension': 0.07484},
#  263: {'mean fractal dimension': 0.05443,
#        'smoothness error': 0.002826,
#        'texture error': 0.9988,
#        'worst fractal dimension': 0.06829},
#  264: {'mean fractal dimension': 0.0558,
#        'smoothness error': 0.004493,
#        'texture error': 0.7383,
#        'worst fractal dimension': 0.0757},
#  265: {'mean fractal dimension': 0.05674,
#        'smoothness error': 0.004551,
#        'texture error': 1.617,
#        'worst fractal dimension': 0.08218},
#  266: {'mean fractal dimension': 0.06491,
#        'smoothness error': 0.00747,
#        'texture error': 1.197,
#        'worst fractal dimension': 0.07587},
#  267: {'mean fractal dimension': 0.05859,
#        'smoothness error': 0.005436,
#        'texture error': 1.916,
#        'worst fractal dimension': 0.07024},
#  268: {'mean fractal dimension': 0.05769,
#        'smoothness error': 0.005518,
#        'texture error': 1.219,
#        'worst fractal dimension': 0.07062},
#  269: {'mean fractal dimension': 0.06862,
#        'smoothness error': 0.008902,
#        'texture error': 1.489,
#        'worst fractal dimension': 0.08701},
#  270: {'mean fractal dimension': 0.05376,
#        'smoothness error': 0.003492,
#        'texture error': 0.7198,
#        'worst fractal dimension': 0.0612},
#  271: {'mean fractal dimension': 0.0627,
#        'smoothness error': 0.006472,
#        'texture error': 0.5293,
#        'worst fractal dimension': 0.08022},
#  272: {'mean fractal dimension': 0.06194,
#        'smoothness error': 0.005687,
#        'texture error': 1.352,
#        'worst fractal dimension': 0.08858},
#  273: {'mean fractal dimension': 0.06312,
#        'smoothness error': 0.0138,
#        'texture error': 1.409,
#        'worst fractal dimension': 0.08175},
#  274: {'mean fractal dimension': 0.0551,
#        'smoothness error': 0.005444,
#        'texture error': 1.433,
#        'worst fractal dimension': 0.07948},
#  275: {'mean fractal dimension': 0.05875,
#        'smoothness error': 0.01418,
#        'texture error': 2.293,
#        'worst fractal dimension': 0.06033},
#  276: {'mean fractal dimension': 0.05821,
#        'smoothness error': 0.008426,
#        'texture error': 1.28,
#        'worst fractal dimension': 0.06386},
#  277: {'mean fractal dimension': 0.04996,
#        'smoothness error': 0.007571,
#        'texture error': 0.828,
#        'worst fractal dimension': 0.05737},
#  278: {'mean fractal dimension': 0.0552,
#        'smoothness error': 0.003741,
#        'texture error': 1.166,
#        'worst fractal dimension': 0.06263},
#  279: {'mean fractal dimension': 0.05853,
#        'smoothness error': 0.004235,
#        'texture error': 0.9195,
#        'worst fractal dimension': 0.06912},
#  280: {'mean fractal dimension': 0.0622,
#        'smoothness error': 0.007392,
#        'texture error': 1.001,
#        'worst fractal dimension': 0.0972},
#  281: {'mean fractal dimension': 0.06113,
#        'smoothness error': 0.008034,
#        'texture error': 1.268,
#        'worst fractal dimension': 0.06688},
#  282: {'mean fractal dimension': 0.05892,
#        'smoothness error': 0.005654,
#        'texture error': 0.9951,
#        'worst fractal dimension': 0.07787},
#  283: {'mean fractal dimension': 0.06684,
#        'smoothness error': 0.004563,
#        'texture error': 0.9173,
#        'worst fractal dimension': 0.1063},
#  284: {'mean fractal dimension': 0.05935,
#        'smoothness error': 0.006418,
#        'texture error': 1.389,
#        'worst fractal dimension': 0.07127},
#  285: {'mean fractal dimension': 0.05855,
#        'smoothness error': 0.006383,
#        'texture error': 1.35,
#        'worst fractal dimension': 0.06431},
#  286: {'mean fractal dimension': 0.06766,
#        'smoothness error': 0.006719,
#        'texture error': 1.39,
#        'worst fractal dimension': 0.09981},
#  287: {'mean fractal dimension': 0.05581,
#        'smoothness error': 0.004731,
#        'texture error': 0.469,
#        'worst fractal dimension': 0.06915},
#  288: {'mean fractal dimension': 0.06233,
#        'smoothness error': 0.01574,
#        'texture error': 1.905,
#        'worst fractal dimension': 0.07009},
#  289: {'mean fractal dimension': 0.05955,
#        'smoothness error': 0.006538,
#        'texture error': 1.974,
#        'worst fractal dimension': 0.06994},
#  290: {'mean fractal dimension': 0.07192,
#        'smoothness error': 0.007762,
#        'texture error': 1.77,
#        'worst fractal dimension': 0.08799},
#  291: {'mean fractal dimension': 0.05852,
#        'smoothness error': 0.005332,
#        'texture error': 0.948,
#        'worst fractal dimension': 0.08472},
#  292: {'mean fractal dimension': 0.0647,
#        'smoothness error': 0.008725,
#        'texture error': 0.7636,
#        'worst fractal dimension': 0.09584},
#  293: {'mean fractal dimension': 0.05715,
#        'smoothness error': 0.007595,
#        'texture error': 1.238,
#        'worst fractal dimension': 0.07007},
#  294: {'mean fractal dimension': 0.061,
#        'smoothness error': 0.006064,
#        'texture error': 0.6931,
#        'worst fractal dimension': 0.06922},
#  295: {'mean fractal dimension': 0.05912,
#        'smoothness error': 0.004348,
#        'texture error': 0.6946,
#        'worst fractal dimension': 0.06794},
#  296: {'mean fractal dimension': 0.06031,
#        'smoothness error': 0.003478,
#        'texture error': 1.027,
#        'worst fractal dimension': 0.06643},
#  297: {'mean fractal dimension': 0.06287,
#        'smoothness error': 0.005596,
#        'texture error': 2.105,
#        'worst fractal dimension': 0.06915},
#  298: {'mean fractal dimension': 0.05586,
#        'smoothness error': 0.003169,
#        'texture error': 0.669,
#        'worst fractal dimension': 0.07676},
#  299: {'mean fractal dimension': 0.06556,
#        'smoothness error': 0.01017,
#        'texture error': 1.143,
#        'worst fractal dimension': 0.06777},
#  300: {'mean fractal dimension': 0.06552,
#        'smoothness error': 0.006056,
#        'texture error': 1.161,
#        'worst fractal dimension': 0.09929},
#  301: {'mean fractal dimension': 0.06249,
#        'smoothness error': 0.00653,
#        'texture error': 1.04,
#        'worst fractal dimension': 0.07764},
#  302: {'mean fractal dimension': 0.07469,
#        'smoothness error': 0.007964,
#        'texture error': 1.743,
#        'worst fractal dimension': 0.09469},
#  303: {'mean fractal dimension': 0.066,
#        'smoothness error': 0.008875,
#        'texture error': 1.563,
#        'worst fractal dimension': 0.07842},
#  304: {'mean fractal dimension': 0.06243,
#        'smoothness error': 0.006652,
#        'texture error': 1.059,
#        'worst fractal dimension': 0.07638},
#  305: {'mean fractal dimension': 0.05878,
#        'smoothness error': 0.006122,
#        'texture error': 1.786,
#        'worst fractal dimension': 0.06745},
#  306: {'mean fractal dimension': 0.05894,
#        'smoothness error': 0.003632,
#        'texture error': 0.5735,
#        'worst fractal dimension': 0.08385},
#  307: {'mean fractal dimension': 0.06833,
#        'smoothness error': 0.007389,
#        'texture error': 1.305,
#        'worst fractal dimension': 0.07804},
#  308: {'mean fractal dimension': 0.05335,
#        'smoothness error': 0.003338,
#        'texture error': 0.6864,
#        'worst fractal dimension': 0.06192},
#  309: {'mean fractal dimension': 0.05518,
#        'smoothness error': 0.004148,
#        'texture error': 0.8285,
#        'worst fractal dimension': 0.0658},
#  310: {'mean fractal dimension': 0.06128,
#        'smoothness error': 0.006064,
#        'texture error': 1.43,
#        'worst fractal dimension': 0.06958},
#  311: {'mean fractal dimension': 0.05255,
#        'smoothness error': 0.005031,
#        'texture error': 0.9115,
#        'worst fractal dimension': 0.05695},
#  312: {'mean fractal dimension': 0.0614,
#        'smoothness error': 0.006494,
#        'texture error': 0.6594,
#        'worst fractal dimension': 0.08253},
#  313: {'mean fractal dimension': 0.061,
#        'smoothness error': 0.004124,
#        'texture error': 0.3602,
#        'worst fractal dimension': 0.07434},
#  314: {'mean fractal dimension': 0.07359,
#        'smoothness error': 0.02075,
#        'texture error': 2.777,
#        'worst fractal dimension': 0.08116},
#  315: {'mean fractal dimension': 0.05673,
# ...
#  465: {'mean fractal dimension': 0.06432,
#        'smoothness error': 0.004929,
#        'texture error': 0.8135,
#        'worst fractal dimension': 0.1249},
#  466: {'mean fractal dimension': 0.0602,
#        'smoothness error': 0.007295,
#        'texture error': 0.7884,
#        'worst fractal dimension': 0.08174},
#  467: {'mean fractal dimension': 0.06412,
#        'smoothness error': 0.01098,
#        'texture error': 1.312,
#        'worst fractal dimension': 0.07875},
#  468: {'mean fractal dimension': 0.07369,
#        'smoothness error': 0.006766,
#        'texture error': 1.465,
#        'worst fractal dimension': 0.1224},
#  469: {'mean fractal dimension': 0.07255,
#        'smoothness error': 0.01459,
#        'texture error': 1.74,
#        'worst fractal dimension': 0.0927},
#  470: {'mean fractal dimension': 0.06413,
#        'smoothness error': 0.007501,
#        'texture error': 1.35,
#        'worst fractal dimension': 0.08524},
#  471: {'mean fractal dimension': 0.05698,
#        'smoothness error': 0.007517,
#        'texture error': 2.643,
#        'worst fractal dimension': 0.06639},
#  472: {'mean fractal dimension': 0.05669,
#        'smoothness error': 0.003271,
#        'texture error': 0.4334,
#        'worst fractal dimension': 0.08273},
#  473: {'mean fractal dimension': 0.0596,
#        'smoothness error': 0.007339,
#        'texture error': 3.647,
#        'worst fractal dimension': 0.06743},
#  474: {'mean fractal dimension': 0.06837,
#        'smoothness error': 0.004474,
#        'texture error': 0.538,
#        'worst fractal dimension': 0.108},
#  475: {'mean fractal dimension': 0.05913,
#        'smoothness error': 0.004873,
#        'texture error': 0.4875,
#        'worst fractal dimension': 0.07802},
#  476: {'mean fractal dimension': 0.06009,
#        'smoothness error': 0.004107,
#        'texture error': 1.018,
#        'worst fractal dimension': 0.07858},
#  477: {'mean fractal dimension': 0.05536,
#        'smoothness error': 0.003308,
#        'texture error': 0.5762,
#        'worst fractal dimension': 0.07698},
#  478: {'mean fractal dimension': 0.06574,
#        'smoothness error': 0.004957,
#        'texture error': 1.166,
#        'worst fractal dimension': 0.0918},
#  479: {'mean fractal dimension': 0.06578,
#        'smoothness error': 0.009197,
#        'texture error': 0.9857,
#        'worst fractal dimension': 0.09136},
#  480: {'mean fractal dimension': 0.06284,
#        'smoothness error': 0.004911,
#        'texture error': 1.19,
#        'worst fractal dimension': 0.07729},
#  481: {'mean fractal dimension': 0.05594,
#        'smoothness error': 0.003704,
#        'texture error': 0.9264,
#        'worst fractal dimension': 0.07603},
#  482: {'mean fractal dimension': 0.06639,
#        'smoothness error': 0.00445,
#        'texture error': 0.5733,
#        'worst fractal dimension': 0.09326},
#  483: {'mean fractal dimension': 0.06088,
#        'smoothness error': 0.003245,
#        'texture error': 0.9462,
#        'worst fractal dimension': 0.0696},
#  484: {'mean fractal dimension': 0.06259,
#        'smoothness error': 0.006034,
#        'texture error': 0.3871,
#        'worst fractal dimension': 0.08181},
#  485: {'mean fractal dimension': 0.07325,
#        'smoothness error': 0.007234,
#        'texture error': 1.207,
#        'worst fractal dimension': 0.1034},
#  486: {'mean fractal dimension': 0.05355,
#        'smoothness error': 0.003535,
#        'texture error': 1.006,
#        'worst fractal dimension': 0.06596},
#  487: {'mean fractal dimension': 0.06115,
#        'smoothness error': 0.005288,
#        'texture error': 1.408,
#        'worst fractal dimension': 0.09009},
#  488: {'mean fractal dimension': 0.06401,
#        'smoothness error': 0.008998,
#        'texture error': 1.154,
#        'worst fractal dimension': 0.08024},
#  489: {'mean fractal dimension': 0.05325,
#        'smoothness error': 0.002667,
#        'texture error': 0.5679,
#        'worst fractal dimension': 0.07623},
#  490: {'mean fractal dimension': 0.05976,
#        'smoothness error': 0.005096,
#        'texture error': 1.139,
#        'worst fractal dimension': 0.08203},
#  491: {'mean fractal dimension': 0.05243,
#        'smoothness error': 0.004369,
#        'texture error': 1.046,
#        'worst fractal dimension': 0.05871},
#  492: {'mean fractal dimension': 0.06077,
#        'smoothness error': 0.007997,
#        'texture error': 1.288,
#        'worst fractal dimension': 0.07625},
#  493: {'mean fractal dimension': 0.06013,
#        'smoothness error': 0.01039,
#        'texture error': 1.486,
#        'worst fractal dimension': 0.07028},
#  494: {'mean fractal dimension': 0.05888,
#        'smoothness error': 0.007802,
#        'texture error': 1.473,
#        'worst fractal dimension': 0.07429},
#  495: {'mean fractal dimension': 0.05748,
#        'smoothness error': 0.005415,
#        'texture error': 1.636,
#        'worst fractal dimension': 0.06599},
#  496: {'mean fractal dimension': 0.06854,
#        'smoothness error': 0.005704,
#        'texture error': 0.6332,
#        'worst fractal dimension': 0.1033},
#  497: {'mean fractal dimension': 0.06046,
#        'smoothness error': 0.003796,
#        'texture error': 0.781,
#        'worst fractal dimension': 0.07661},
#  498: {'mean fractal dimension': 0.06697,
#        'smoothness error': 0.007974,
#        'texture error': 1.045,
#        'worst fractal dimension': 0.09445},
#  499: {'mean fractal dimension': 0.06222,
#        'smoothness error': 0.006666,
#        'texture error': 1.216,
#        'worst fractal dimension': 0.08999},
#  500: {'mean fractal dimension': 0.06869,
#        'smoothness error': 0.004123,
#        'texture error': 0.8423,
#        'worst fractal dimension': 0.08549},
#  501: {'mean fractal dimension': 0.07237,
#        'smoothness error': 0.00968,
#        'texture error': 1.528,
#        'worst fractal dimension': 0.1183},
#  502: {'mean fractal dimension': 0.06612,
#        'smoothness error': 0.009702,
#        'texture error': 1.095,
#        'worst fractal dimension': 0.07538},
#  503: {'mean fractal dimension': 0.05484,
#        'smoothness error': 0.005753,
#        'texture error': 0.7452,
#        'worst fractal dimension': 0.07277},
#  504: {'mean fractal dimension': 0.09502,
#        'smoothness error': 0.009783,
#        'texture error': 1.093,
#        'worst fractal dimension': 0.1252},
#  505: {'mean fractal dimension': 0.09575,
#        'smoothness error': 0.02177,
#        'texture error': 1.39,
#        'worst fractal dimension': 0.1364},
#  506: {'mean fractal dimension': 0.06894,
#        'smoothness error': 0.006272,
#        'texture error': 0.7959,
#        'worst fractal dimension': 0.08839},
#  507: {'mean fractal dimension': 0.07976,
#        'smoothness error': 0.01262,
#        'texture error': 1.03,
#        'worst fractal dimension': 0.1168},
#  508: {'mean fractal dimension': 0.05657,
#        'smoothness error': 0.007394,
#        'texture error': 0.4706,
#        'worst fractal dimension': 0.0723},
#  509: {'mean fractal dimension': 0.07083,
#        'smoothness error': 0.009538,
#        'texture error': 1.961,
#        'worst fractal dimension': 0.1067},
#  510: {'mean fractal dimension': 0.06758,
#        'smoothness error': 0.006982,
#        'texture error': 0.6417,
#        'worst fractal dimension': 0.09879},
#  511: {'mean fractal dimension': 0.05348,
#        'smoothness error': 0.006708,
#        'texture error': 0.6232,
#        'worst fractal dimension': 0.06142},
#  512: {'mean fractal dimension': 0.07325,
#        'smoothness error': 0.005414,
#        'texture error': 0.9306,
#        'worst fractal dimension': 0.1109},
#  513: {'mean fractal dimension': 0.0564,
#        'smoothness error': 0.004953,
#        'texture error': 0.6237,
#        'worst fractal dimension': 0.07048},
#  514: {'mean fractal dimension': 0.05915,
#        'smoothness error': 0.004952,
#        'texture error': 1.198,
#        'worst fractal dimension': 0.06954},
#  515: {'mean fractal dimension': 0.06211,
#        'smoothness error': 0.008577,
#        'texture error': 1.01,
#        'worst fractal dimension': 0.06783},
#  516: {'mean fractal dimension': 0.05941,
#        'smoothness error': 0.006176,
#        'texture error': 0.9225,
#        'worst fractal dimension': 0.07863},
#  517: {'mean fractal dimension': 0.06188,
#        'smoothness error': 0.005089,
#        'texture error': 0.8737,
#        'worst fractal dimension': 0.09136},
#  518: {'mean fractal dimension': 0.07253,
#        'smoothness error': 0.005273,
#        'texture error': 1.169,
#        'worst fractal dimension': 0.08893},
#  519: {'mean fractal dimension': 0.06623,
#        'smoothness error': 0.007509,
#        'texture error': 1.003,
#        'worst fractal dimension': 0.08557},
#  520: {'mean fractal dimension': 0.07696,
#        'smoothness error': 0.01546,
#        'texture error': 1.13,
#        'worst fractal dimension': 0.08982},
#  521: {'mean fractal dimension': 0.06739,
#        'smoothness error': 0.004989,
#        'texture error': 0.9004,
#        'worst fractal dimension': 0.09671},
#  522: {'mean fractal dimension': 0.06343,
#        'smoothness error': 0.0042,
#        'texture error': 1.083,
#        'worst fractal dimension': 0.07613},
#  523: {'mean fractal dimension': 0.06843,
#        'smoothness error': 0.006739,
#        'texture error': 1.249,
#        'worst fractal dimension': 0.09031},
#  524: {'mean fractal dimension': 0.06891,
#        'smoothness error': 0.008732,
#        'texture error': 1.216,
#        'worst fractal dimension': 0.09209},
#  525: {'mean fractal dimension': 0.07126,
#        'smoothness error': 0.007897,
#        'texture error': 0.6793,
#        'worst fractal dimension': 0.1049},
#  526: {'mean fractal dimension': 0.06317,
#        'smoothness error': 0.004413,
#        'texture error': 0.6068,
#        'worst fractal dimension': 0.08665},
#  527: {'mean fractal dimension': 0.05808,
#        'smoothness error': 0.003681,
#        'texture error': 0.4957,
#        'worst fractal dimension': 0.07592},
#  528: {'mean fractal dimension': 0.06457,
#        'smoothness error': 0.01004,
#        'texture error': 2.635,
#        'worst fractal dimension': 0.07253},
#  529: {'mean fractal dimension': 0.06608,
#        'smoothness error': 0.007327,
#        'texture error': 0.504,
#        'worst fractal dimension': 0.08052},
#  530: {'mean fractal dimension': 0.06677,
#        'smoothness error': 0.006587,
#        'texture error': 1.907,
#        'worst fractal dimension': 0.07757},
#  531: {'mean fractal dimension': 0.06461,
#        'smoothness error': 0.005251,
#        'texture error': 0.8745,
#        'worst fractal dimension': 0.0895},
#  532: {'mean fractal dimension': 0.06155,
#        'smoothness error': 0.003828,
#        'texture error': 0.4801,
#        'worst fractal dimension': 0.07782},
#  533: {'mean fractal dimension': 0.05419,
#        'smoothness error': 0.004938,
#        'texture error': 1.736,
#        'worst fractal dimension': 0.06386},
#  534: {'mean fractal dimension': 0.06408,
#        'smoothness error': 0.009501,
#        'texture error': 1.583,
#        'worst fractal dimension': 0.08278},
#  535: {'mean fractal dimension': 0.06251,
#        'smoothness error': 0.004578,
#        'texture error': 0.9901,
#        'worst fractal dimension': 0.07569},
#  536: {'mean fractal dimension': 0.05982,
#        'smoothness error': 0.006113,
#        'texture error': 1.851,
#        'worst fractal dimension': 0.08351},
#  537: {'mean fractal dimension': 0.07405,
#        'smoothness error': 0.01288,
#        'texture error': 1.978,
#        'worst fractal dimension': 0.0997},
#  538: {'mean fractal dimension': 0.07285,
#        'smoothness error': 0.01266,
#        'texture error': 1.462,
#        'worst fractal dimension': 0.09938},
#  539: {'mean fractal dimension': 0.07751,
#        'smoothness error': 0.01547,
#        'texture error': 1.479,
#        'worst fractal dimension': 0.1066},
#  540: {'mean fractal dimension': 0.06782,
#        'smoothness error': 0.01215,
#        'texture error': 1.768,
#        'worst fractal dimension': 0.08134},
#  541: {'mean fractal dimension': 0.06341,
#        'smoothness error': 0.007138,
#        'texture error': 1.079,
#        'worst fractal dimension': 0.1023},
#  542: {'mean fractal dimension': 0.0568,
#        'smoothness error': 0.004775,
#        'texture error': 1.385,
#        'worst fractal dimension': 0.06956},
#  543: {'mean fractal dimension': 0.05781,
#        'smoothness error': 0.004973,
#        'texture error': 1.597,
#        'worst fractal dimension': 0.06443},
#  544: {'mean fractal dimension': 0.06688,
#        'smoothness error': 0.006298,
#        'texture error': 1.047,
#        'worst fractal dimension': 0.08492},
#  545: {'mean fractal dimension': 0.05801,
#        'smoothness error': 0.005868,
#        'texture error': 1.336,
#        'worst fractal dimension': 0.06953},
#  546: {'mean fractal dimension': 0.06201,
#        'smoothness error': 0.007086,
#        'texture error': 0.967,
#        'worst fractal dimension': 0.07399},
#  547: {'mean fractal dimension': 0.06714,
#        'smoothness error': 0.01027,
#        'texture error': 1.023,
#        'worst fractal dimension': 0.09479},
#  548: {'mean fractal dimension': 0.06235,
#        'smoothness error': 0.00744,
#        'texture error': 1.363,
#        'worst fractal dimension': 0.0792},
#  549: {'mean fractal dimension': 0.06328,
#        'smoothness error': 0.008263,
#        'texture error': 1.918,
#        'worst fractal dimension': 0.07626},
#  550: {'mean fractal dimension': 0.05948,
#        'smoothness error': 0.009579,
#        'texture error': 1.304,
#        'worst fractal dimension': 0.06592},
#  551: {'mean fractal dimension': 0.06552,
#        'smoothness error': 0.003495,
#        'texture error': 1.467,
#        'worst fractal dimension': 0.08032},
#  552: {'mean fractal dimension': 0.05637,
#        'smoothness error': 0.008835,
#        'texture error': 1.367,
#        'worst fractal dimension': 0.06484},
#  553: {'mean fractal dimension': 0.06576,
#        'smoothness error': 0.01094,
#        'texture error': 1.879,
#        'worst fractal dimension': 0.07393},
#  554: {'mean fractal dimension': 0.05708,
#        'smoothness error': 0.008412,
#        'texture error': 1.36,
#        'worst fractal dimension': 0.07242},
#  555: {'mean fractal dimension': 0.06127,
#        'smoothness error': 0.01205,
#        'texture error': 2.239,
#        'worst fractal dimension': 0.08283},
#  556: {'mean fractal dimension': 0.06331,
#        'smoothness error': 0.01291,
#        'texture error': 2.09,
#        'worst fractal dimension': 0.06742},
#  557: {'mean fractal dimension': 0.06059,
#        'smoothness error': 0.01159,
#        'texture error': 2.927,
#        'worst fractal dimension': 0.06969},
#  558: {'mean fractal dimension': 0.06147,
#        'smoothness error': 0.004242,
#        'texture error': 1.108,
#        'worst fractal dimension': 0.08004},
#  559: {'mean fractal dimension': 0.0657,
#        'smoothness error': 0.0082,
#        'texture error': 2.904,
#        'worst fractal dimension': 0.08732},
#  560: {'mean fractal dimension': 0.06171,
#        'smoothness error': 0.007256,
#        'texture error': 1.492,
#        'worst fractal dimension': 0.08321},
#  561: {'mean fractal dimension': 0.05502,
#        'smoothness error': 0.007594,
#        'texture error': 3.896,
#        'worst fractal dimension': 0.05905},
#  562: {'mean fractal dimension': 0.07152,
#        'smoothness error': 0.004625,
#        'texture error': 1.205,
#        'worst fractal dimension': 0.1409},
#  563: {'mean fractal dimension': 0.06879,
#        'smoothness error': 0.006399,
#        'texture error': 1.026,
#        'worst fractal dimension': 0.09873},
#  564: {'mean fractal dimension': 0.05623,
#        'smoothness error': 0.0103,
#        'texture error': 1.256,
#        'worst fractal dimension': 0.07115},
#  565: {'mean fractal dimension': 0.05533,
#        'smoothness error': 0.005769,
#        'texture error': 2.463,
#        'worst fractal dimension': 0.06637},
#  566: {'mean fractal dimension': 0.05648,
#        'smoothness error': 0.005903,
#        'texture error': 1.075,
#        'worst fractal dimension': 0.0782},
#  567: {'mean fractal dimension': 0.07016,
#        'smoothness error': 0.006522,
#        'texture error': 1.595,
#        'worst fractal dimension': 0.124},
#  568: {'mean fractal dimension': 0.05884,
#        'smoothness error': 0.007189,
#        'texture error': 1.428,
#        'worst fractal dimension': 0.07039}}

# %%
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst radius  worst texture  worst perimeter  \
# 0                 0.07871  ...         25.38          17.33           184.60
# 1                 0.05667  ...         24.99          23.41           158.80
# 2                 0.05999  ...         23.57          25.53           152.50
# 3                 0.09744  ...         14.91          26.50            98.87
# 4                 0.05883  ...         22.54          16.67           152.20
#
#    worst area  worst smoothness  worst compactness  worst concavity  \
# 0      2019.0            0.1622             0.6656           0.7119
# 1      1956.0            0.1238             0.1866           0.2416
# 2      1709.0            0.1444             0.4245           0.4504
# 3       567.7            0.2098             0.8663           0.6869
# 4      1575.0            0.1374             0.2050           0.4000
#
#    worst concave points  worst symmetry  worst fractal dimension
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 2                0.2430          0.3613                  0.08758
# 3                0.2575          0.6638                  0.17300
# 4                0.1625          0.2364                  0.07678
#
# [5 rows x 30 columns]

# %%
n_pcs = pca_breast.components_[:2]
n_pcs[0].shape
# Out:
# (30,)

# %%
most_important = [np.abs(pca_breast.components_[i]).argmax() for i in range(n_pcs)]

# %%
most_important
# Out:
# [7, 9, 11, 21, 4, 28, 29, 14, 16, 8]

# %%
features = breast.feature_names
features.shape
# Out:
# (569,)

# %%
for i in features:
    print(i)
# Out:
# mean radius
# mean texture
# mean perimeter
# mean area
# mean smoothness
# mean compactness
# mean concavity
# mean concave points
# mean symmetry
# mean fractal dimension
# radius error
# texture error
# perimeter error
# area error
# smoothness error
# compactness error
# concavity error
# concave points error
# symmetry error
# fractal dimension error
# worst radius
# worst texture
# worst perimeter
# worst area
# worst smoothness
# worst compactness
# worst concavity
# worst concave points
# worst symmetry
# worst fractal dimension

# %%
data_send = {}
count = 0
for i, j, k in zip(features, pca_breast.components_[0], pca_breast.components_[1]):
    data_send[count] = {}
    data_send[count]["name"] = i
    data_send[count]["pc1"] = j
    data_send[count]["pc2"] = k
    count += 1

# %%
data_send
# Out:
# {0: {'name': 'mean radius',
#   'pc1': 0.21890244370001577,
#   'pc2': -0.233857131747535},
#  1: {'name': 'mean texture',
#   'pc1': 0.10372457821567597,
#   'pc2': -0.05970608829080295},
#  2: {'name': 'mean perimeter',
#   'pc1': 0.2275372930056408,
#   'pc2': -0.21518136139684982},
#  3: {'name': 'mean area',
#   'pc1': 0.22099498538594436,
#   'pc2': -0.23107671128362745},
#  4: {'name': 'mean smoothness',
#   'pc1': 0.14258969436025495,
#   'pc2': 0.18611302267032268},
#  5: {'name': 'mean compactness',
#   'pc1': 0.23928535395301204,
#   'pc2': 0.15189161007283025},
#  6: {'name': 'mean concavity',
#   'pc1': 0.25840048124874004,
#   'pc2': 0.0601653627989567},
#  7: {'name': 'mean concave points',
#   'pc1': 0.26085375838568264,
#   'pc2': -0.03476750049364384},
#  8: {'name': 'mean symmetry',
#   'pc1': 0.13816695930365536,
#   'pc2': 0.19034877037208467},
#  9: {'name': 'mean fractal dimension',
#   'pc1': 0.06436334637180302,
#   'pc2': 0.3665754713785027},
#  10: {'name': 'radius error',
#   'pc1': 0.20597877585522775,
#   'pc2': -0.105552151826104},
#  11: {'name': 'texture error',
#   'pc1': 0.017428028148939064,
#   'pc2': 0.08997968182955343},
#  12: {'name': 'perimeter error',
#   'pc1': 0.21132591637552867,
#   'pc2': -0.08945723422100084},
#  13: {'name': 'area error',
#   'pc1': 0.20286963544140807,
#   'pc2': -0.15229262810527183},
#  14: {'name': 'smoothness error',
#   'pc1': 0.014531452147855336,
#   'pc2': 0.20443045302975013},
#  15: {'name': 'compactness error',
#   'pc1': 0.17039345120742944,
#   'pc2': 0.23271589619052446},
#  16: {'name': 'concavity error',
#   'pc1': 0.15358978973977216,
#   'pc2': 0.19720728271075533},
#  17: {'name': 'concave points error',
#   'pc1': 0.1834173969641168,
#   'pc2': 0.1303215599076057},
#  18: {'name': 'symmetry error',
#   'pc1': 0.04249842163304167,
#   'pc2': 0.18384799994442094},
#  19: {'name': 'fractal dimension error',
#   'pc1': 0.10256832209561646,
#   'pc2': 0.2800920266123792},
#  20: {'name': 'worst radius',
#   'pc1': 0.2279966342324634,
#   'pc2': -0.21986637930007072},
#  21: {'name': 'worst texture',
#   'pc1': 0.10446932545723345,
#   'pc2': -0.04546729827108406},
#  22: {'name': 'worst perimeter',
#   'pc1': 0.23663968074165845,
#   'pc2': -0.1998784279410524},
#  23: {'name': 'worst area',
#   'pc1': 0.2248705327341829,
#   'pc2': -0.21935185792236406},
#  24: {'name': 'worst smoothness',
#   'pc1': 0.12795256119283224,
#   'pc2': 0.17230435165224395},
#  25: {'name': 'worst compactness',
#   'pc1': 0.21009588015783354,
#   'pc2': 0.14359317327176851},
#  26: {'name': 'worst concavity',
#   'pc1': 0.22876753281507123,
#   'pc2': 0.09796411433615079},
#  27: {'name': 'worst concave points',
#   'pc1': 0.25088597121804107,
#   'pc2': -0.008257235069985415},
#  28: {'name': 'worst symmetry',
#   'pc1': 0.12290455637796138,
#   'pc2': 0.14188334860251317},
#  29: {'name': 'worst fractal dimension',
#   'pc1': 0.13178394287790116,
#   'pc2': 0.27533946858033864}}
